# %%
# !nvidia-smi
# !python -c "import torch; print(torch.__version__, torch.cuda.is_available())"

# %%
# clone your project
# !git clone https://github.com/TiaanViviers/Fast_BOCPD.git

# go into benchmarks
# %cd Fast_BOCPD/benchmarks

# go into competitors
# %cd competitors

# clone hildensia competitor
# !git clone https://github.com/hildensia/bayesian_changepoint_detection.git

# install hildensia in editable mode
# %cd bayesian_changepoint_detection
# !pip install -e .

# go back to scripts directory (where benchmark runner lives)
# %cd ../../scripts

# %%
#generate data
# !python generate_data.py gaussian 1000 150

# %%
# !python benchmark_competitors.py --lib hildensia --device cuda
